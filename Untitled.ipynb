# %% [markdown]
# Discrete Optimization course on Coursera : https://www.coursera.org/learn/discrete-optimization/home/welcome
#
# Week 1:
#
# # Knap sack problem

# %%
from time import time
from IPython.display import Image

# %%
# [value, weight]
items = [ [1,2],[1,2],[1,2],[10,5],[10,5],[13,8],[7,3] ]
K = 10

# %%
n = len(items)

# %% [markdown]
# ## Greedy procedure
# #### 1. lightest first:

# %%
def greedy1(K,items):
    n = len(items)
    # Sorting by ascending weight
    items.sort(key=lambda x: x[1])
    print("sorted by weight: %s" % items)
    selected_value = 0
    selected_weight = 0
    selected = []
    i = 0

    # Packing lightest items first
    while selected_weight < K:
        if i>=n:
            break;
        if selected_weight+items[i][1] <= K:
            selected.append(items[i])
            selected_weight += items[i][1]
            selected_value += items[i][0]
            i += 1
        else:
            break;
    return selected, selected_weight, selected_value

selected, selected_weight, selected_value = greedy1(10,items)
print("for a weight of %d" % selected_weight)
print("for a value of %d" % selected_value)
print("Selected items to pack are : \n %s " % selected)
# Out:
# sorted by weight: [[1, 2], [1, 2], [1, 2], [7, 3], [10, 5], [10, 5], [13, 8]]
# for a weight of 9
# for a value of 10
# Selected items to pack are :
#  [[1, 2], [1, 2], [1, 2], [7, 3]]

# %% [markdown]
#  #### 2. Most valuable first

# %%
def greedy0(K,items):
    n = len(items)
    # Sorting by descending value
    items.sort(key=lambda x: x[0], reverse=True)
    print("sorted by value: %s" % items)
    selected_value = 0
    selected_weight = 0
    selected = []

    # Packing most valuable first if it still fits
    for i in range(n):
        if selected_weight+items[i][1] <= K:
            selected.append(items[i])
            selected_weight += items[i][1]
            selected_value += items[i][0]
    return selected, selected_weight, selected_value

selected, selected_weight, selected_value = greedy0(10,items)        
print("for a weight of %d" % selected_weight)
print("for a value of %d" % selected_value)
print("Selected items to pack are : \n %s " % selected)
# Out:
# sorted by value: [[13, 8], [10, 5], [10, 5], [7, 3], [1, 2], [1, 2], [1, 2]]
# for a weight of 10
# for a value of 14
# Selected items to pack are :
#  [[13, 8], [1, 2]]

# %% [markdown]
# #### 3. Value density

# %%
def greedy(K,items):
    n = len(items)
    # Sorting by density : ie. value / weight
    items.sort(key=lambda x: x[0]/x[1], reverse=True)
    print("sorted by value density: %s" % items)
    selected_value = 0
    selected_weight = 0
    selected = []

    # Packing most valuable first if it still fits
    for i in range(n):
        if selected_weight+items[i][1] <= K:
            selected.append(items[i])
            selected_weight += items[i][1]
            selected_value += items[i][0]
    return selected, selected_weight, selected_value

selected, selected_weight, selected_value = greedy(10,items)
print("for a weight of %d" % selected_weight)
print("for a value of %d" % selected_value)
print("Selected items to pack are : \n %s " % selected)
# Out:
# sorted by value density: [[7, 3], [10, 5], [10, 5], [13, 8], [1, 2], [1, 2], [1, 2]]
# for a weight of 10
# for a value of 18
# Selected items to pack are :
#  [[7, 3], [10, 5], [1, 2]]

# %% [markdown]
# ### Overview:
# *
#
# Depends on the chosen heuristic
#
# +
#
# quick to design
#
# can be very fast to run
#
# -
#
# no guarantee on quality
#
# feasibility needs to be easy
#
# quality varies between instances

# %% [markdown]
# ## Modeling

# %% [markdown]
# maximisation problem
#
# - Decision variable:
#
# $\begin{cases}
#     x_i = 1 := pack\hspace{1mm} the\hspace{1mm}  i-th\hspace{1mm}  item
#     \newline x_i = 0 := Don't\hspace{1mm} pack\hspace{1mm} the\hspace{1mm} i-th\hspace{1mm} item
# \end{cases}$
#
# - Problem Constraint:
#
# $\sum\limits_{i\in I}w_ix_i \le K$
#
# - Objective function:
#
# $\sum\limits_{i\in I}v_ix_i$

# %% [markdown]
# ## Dynamic programming

# %% [markdown]
# * Finds Best Solution
# * Divide and conquer / Bottom up computation  technique
# * We denote o(k,j) the optimal solution for the alternative problem with maximum capacity k and for the items 1..j to solve the original problem o(K,n)
# * Procedure:
#     - If item fits: O(k,j) = max{ O(k,j-1), v$_j$+O(k-w$_j$,j-1) }
#     - If it doesn't O(k,j) = O(k,j-1)
#
# recursion starting from o(k,0)=0 for all k

# %% [markdown]
# #### 1. Top down version :
# Inefficient and not a dynamic programming solution

# %%
def o(k,j):
    if j==0: #first recursion term
        return 0
    elif items[j-1][1] <= k: #if item fits
        return max(o(k,j-1), items[j-1][0]+o(k-items[j-1][1],j-1) )
    else: #if item doesn't fit
        return o(k,j-1)

start = time()
print("Optimal reachable value : %d" % o(10,n))
print("run time : %f ms" % (1000*(time()-start)))
# Out:
# Optimal reachable value : 20
# run time : 0.489473 ms

# %% [markdown]
# #### 1. Bottom up version :
# O(Kn) solution but not polynomial because of the capacity K -> $log_2K$ bits
#
# $\Rightarrow$ pseudo-polynomial

# %%
Image("TableDynamicProgramming1.png")

# %%
Image("TableDynamicProgramming2.png")

# %%
# A python improvement using memoization
from functools import lru_cache

@lru_cache(maxsize = 250)
def dp_o(k,j,items):
    if j==0: #first recursion term
        return 0
    elif items[j-1][1] <= k: #if item fits
        return max(o(k,j-1), items[j-1][0]+o(k-items[j-1][1],j-1) )
    else: #if item doesn't fit
        return o(k,j-1)

start = time()
print("Optimal reachable value : %d" % dp_o(K,n,items))
print("run time : %f ms" % (1000*(time()-start)))
# Out:
# Optimal reachable value : 20
# run time : 0.268459 ms

# %%
def dynamic_prog(K,items):
    # Explicit dynamic programming implementation
    n = len(items)
    dp_table = []
    j_col = []

    # first column of zeros
    for k in range(K+1):
        j_col.append(0)
    dp_table.append(j_col)
    # filling other columns 
    for j in range(n):
        j_col = []
        for k in range(K+1):
            if items[j][1] <= k: #item fits
                j_col.append( max( dp_table[j][k], items[j][0]+dp_table[j][k-items[j][1]] ) )
            else:
                j_col.append( dp_table[j][k] )
        dp_table.append(j_col)
    
    return dp_table
    
dp_table = dynamic_prog(10,items)    
start = time()    
print("Optimal reachable value : %d" % dp_table[n][K])
print("run time : %f ms" % (1000*(time()-start)))
# Out:
# Optimal reachable value : 20
# run time : 0.215054 ms

# %% [markdown]
# ## Branch and bound

# %%
items2 = [[45,5],[48,8],[35,3]]
dynamic_prog(10,items2)[len(items2)][10]
# Out:
# 80

# %% [markdown]
# maximize $45x_1+48x_2+35x_3$
#
# subject to
# $\begin{cases}
#     5x_1+8x_2+3x_3 \le 10
#     \newline x_i \in \{0,1\} \quad ,i\in \{1,2,3\}
# \end{cases}$

# %% [markdown]
# **Branching:**
#     split problem into a number of subproblems ~ exhaustive search
#
# **Bounding:**
#     find an optimistic estimate; an upper bound for the maximization problems.
#
# #### 1. Relaxation: removing capacity constraint :
#  Choosing all available items.

# %%
Image("NoConstraint_B&B.png")

# %% [markdown]
# #### 1. Linear Relaxation:
#  maximize $45x_1+48x_2+35x_3$
#
# subject to
# $\begin{cases}
#     5x_1+8x_2+3x_3 \le 10
#     \newline 0 \le x_i \le 1
# \end{cases}$

# %%
Image("LinearRelax_B&B.png")

# %% [markdown]
# At each step, we bound by the value given by the linear relaxation which can be easily solved thanks to the greedy algorithm using density value and taking fractions of the objects if needed.
#
# We stop the exploration as the estimate (77) is lower than the already retrieved solution (80)

# %% [markdown]
# ## Search Strategies
#
# #### Depth-first:
# go deeper in the tree and prune when a node's estimation is worse than the best solution found
# memory efficient : at most one whole branch so the number of the items
# #### Best-first:
# always explore the node with the best estimation
# #### Least discrepancy:
# - avoid mistakes (defined by trusting a greedy heuristic)
# - explore the space by allowing an increasing number of mistakes through waves
#
# + probes the search space
# eg. heuristic is going left

# %%
Image("LDS.png")
